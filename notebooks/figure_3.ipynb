# %% [markdown]
# # Figure 3. Continuous whole-report results for orientation stimuli

# %% [markdown]
# ### Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from data import load_data
from utils import get_relative_dist_df, get_kl_df
from vis import FREE_ORIENT, RAND_ORIENT, plot_error_by_set_size, plot_error_by_response, set_axes_labels, set_export_style, plot_paired_error_by_set_size, plot_paired_error_by_response, set_axes_aspect, plot_paired_relative_distance, plot_relative_distance_scatter

save_fig = False

# %% [markdown]
# ### Load data

# %%
### DATASET LOADING ###
modality = 'orient'
set_size = 6 # for response plotting

# continuous datasets
df_free_cont = load_data(modality=modality, condition='free', dataset='continuous')
df_free_cont_6 = df_free_cont[df_free_cont.set_size == set_size].reset_index(drop=True)

df_rand_cont = load_data(modality=modality, condition='rand', dataset='continuous')
df_rand_cont_6 = df_rand_cont[df_rand_cont.set_size == set_size].reset_index(drop=True)

# %% [markdown]
# ### Figure 3A. Error distributions by set size

# %%
# have to pass unique colors for orientation
paired_colors = [FREE_ORIENT, RAND_ORIENT]

# %%
## errors by set size (ORIENT)##
fig, axes = plot_paired_error_by_set_size(df_free_cont, df_rand_cont, bins=90, paired_colors=paired_colors)

for ax, ss in zip(axes[1:], [2, 3, 4, 6]):
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_xticks([])
    ax.set_xticklabels([])
    ax.set_yticks([])
    ax.set_ylim(-.15,.15)

axes[0].set_ylim(-.15, .15)
axes[0].set_yticks([-.15, 0, .15])
axes[0].set_yticklabels([0.15, 0, 0.15])
axes[0].spines['left'].set_position(('outward',10))
axes[0].spines['bottom'].set_position(('outward',10))
axes[0].spines['right'].set_visible(False)
axes[0].spines['top'].set_visible(False)


set_axes_aspect(fig, axes)
set_export_style(fig, axes, remove_ticklabels=False, figsize=(10, 3))

if save_fig:
    plt.savefig('../figures/fig_07-01_cumulative_error_cont_ori.png', bbox_inches='tight', dpi=800)

plt.show()

# %% [markdown]
# ### Figure 3A. Error distributions by report order (set size 6)

# %%
## errors by response (ORIENT)
fig, axes = plot_paired_error_by_response(df_free_cont_6, df_rand_cont_6, bins=90, paired_colors=paired_colors)

for ax, ss in zip(axes[1:], [2, 3, 4, 6, 8]):
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_xticks([])
    ax.set_xticklabels([])
    ax.set_yticks([])
    ax.set_ylim(-.1,.1)

axes[0].set_yticks([-.1, 0, .1])
axes[0].set_yticklabels([.1, 0, .1])
axes[0].spines['left'].set_position(('outward',10))
axes[0].spines['bottom'].set_position(('outward',10))
axes[0].spines['right'].set_visible(False)
axes[0].spines['top'].set_visible(False)
axes[0].set_ylim(-.1, .1)

set_axes_aspect(fig, axes)
set_export_style(fig, axes, remove_ticklabels=False, figsize=(10, 3))

plt.subplots_adjust(wspace=0.1)

if save_fig:
    plt.savefig('../figures/fig_07-02_response_error_cont_ori.png', bbox_inches='tight', dpi=800)

plt.show()

# %% [markdown]
# ### Joint distributions (not published)

# %%
# continuous joint distributions- free

fig, axes = plot_relative_distance_scatter(df_free_cont_6, size=15, color=FREE_ORIENT)

for ax in axes[1:]:
    ax.set_xticks([])
    ax.set_xticklabels([])
    ax.set_yticks([])
    ax.set_yticklabels([])
    ax.set_xlabel('')
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

axes[0].set_xlabel('reported (rad)')
axes[0].set_ylabel('first reported (rad)')
axes[0].spines['right'].set_visible(False)
axes[0].spines['top'].set_visible(False)
axes[0].spines['left'].set_position(('outward',5))
axes[0].spines['left'].set_bounds(-np.pi, np.pi)
axes[0].spines['bottom'].set_position(('outward',5))
axes[0].spines['bottom'].set_bounds(-np.pi, np.pi)

set_axes_aspect(fig, axes)
set_export_style(fig, axes, remove_ticklabels=False, figsize=(10, 3))

if save_fig:
    plt.savefig('../figures/fig_02-01_cont_joint_dists.png', bbox_inches='tight', dpi=800)

plt.show()

# %%
# continuous joint distributions- rand

fig, axes = plot_relative_distance_scatter(df_rand_cont_6, size=15, color=RAND_ORIENT)

for ax in axes[1:]:
    ax.set_xticks([])
    ax.set_xticklabels([])
    ax.set_yticks([])
    ax.set_yticklabels([])
    ax.set_xlabel('')
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

axes[0].set_xlabel('reported (rad)')
axes[0].set_ylabel('first reported (rad)')
axes[0].spines['right'].set_visible(False)
axes[0].spines['top'].set_visible(False)
axes[0].spines['left'].set_position(('outward',5))
axes[0].spines['left'].set_bounds(-np.pi, np.pi)
axes[0].spines['bottom'].set_position(('outward',5))
axes[0].spines['bottom'].set_bounds(-np.pi, np.pi)

set_axes_aspect(fig, axes)
set_export_style(fig, axes, remove_ticklabels=False, figsize=(10, 3))

if save_fig:
    plt.savefig('../figures/fig_02-01_disc_joint_dists.png', bbox_inches='tight', dpi=800)

plt.show()

# %% [markdown]
# ### Figure 3B. Relative error distributions

# %%
# relative dists (orientation)

dist_df_upper, axes = plot_paired_relative_distance(df_free_cont_6, df_rand_cont_6, paired_colors=paired_colors)

for ax in axes[1:]:
    ax.set_xticks([])
    ax.set_xticklabels([])
    ax.set_ylim(-0.06, 0.06)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

axes[0].spines['right'].set_visible(False)
axes[0].spines['top'].set_visible(False)
axes[0].spines['left'].set_position(('outward',10))
axes[0].spines['bottom'].set_position(('outward',10))
axes[0].set_ylim([-0.06, 0.06])
axes[0].set_yticks([-0.06, 0, 0.06])
axes[0].set_yticklabels([0.06, 0, 0.06])

set_axes_aspect(fig, axes)
set_export_style(fig, axes, remove_ticklabels=False, figsize=(10, 3))

if save_fig:
    plt.savefig('../figures/fig_07-03_relative_dists_cont_ori.png', bbox_inches='tight', dpi=800)

plt.show()

# %% [markdown]
# ### KL divergence estimation

# %%
def get_bootstrapped_KL_by_sub(df_free, df_rand, kl_bins=36, n_iters=1000, sample_bins=360, empirical=True):
    
    kl_df = None
    free_subs = np.sort(df_free.subject.unique())
    rand_subs = np.sort(df_rand.subject.unique())
    total_subs = len(free_subs) + len(rand_subs)
    sub_count = 0

    for sub in free_subs:
        data_free = df_free[df_free.subject == sub]
        
        kl_df_free = get_kl_df(data_free, 
                               n_iters=n_iters, 
                               condition='free', 
                               kl_bins=kl_bins, 
                               empirical=empirical)
        kl_df_base_free = get_kl_df(data_free, 
                                    n_iters=n_iters, 
                                    uniform=True, 
                                    sample_bins=sample_bins, 
                                    condition='baseline_free',
                                    kl_bins=kl_bins, 
                                    empirical=empirical)

        kl_df_sub = pd.concat([kl_df_free, kl_df_base_free])
        kl_df_sub['subject'] = sub
        
        kl_df = kl_df_sub if kl_df is None else pd.concat([kl_df, kl_df_sub])

        sub_count += 1
        print(f'{sub_count} / {total_subs} subjects complete')

    for sub in rand_subs:
        data_rand = df_rand[df_rand.subject == sub]
        
        kl_df_rand = get_kl_df(data_rand, 
                               n_iters=n_iters, 
                               condition='rand', 
                               kl_bins=kl_bins, 
                               empirical=empirical)
        kl_df_base_rand = get_kl_df(data_rand, 
                                    n_iters=n_iters, 
                                    uniform=True, 
                                    sample_bins=sample_bins, 
                                    condition='baseline_rand',
                                    kl_bins=kl_bins, 
                                    empirical=empirical)

        kl_df_sub = pd.concat([kl_df_rand, kl_df_base_rand])
        kl_df_sub['subject'] = sub
        
        kl_df = pd.concat([kl_df, kl_df_sub])

        sub_count += 1
        print(f'{sub_count} / {total_subs} subjects complete')

    return kl_df

# %%
# compute bootstrapped KL estimates by sub/condition (orientation, continuous)
# this takes several minutes 

kl_df_orient = get_bootstrapped_KL_by_sub(df_free_cont_6, df_rand_cont_6, kl_bins=36, n_iters=10, sample_bins=360, empirical=True)

# compute KL estimates for color task to compare
df_free_cont_color = load_data(modality='color', condition='free', dataset='continuous')
df_free_cont_6_color = df_free_cont_color[df_free_cont_color.set_size == 6].reset_index(drop=True)

df_rand_cont_color = load_data(modality='color', condition='rand', dataset='continuous')
df_rand_cont_6_color = df_rand_cont_color[df_rand_cont_color.set_size == 6].reset_index(drop=True)

kl_df_color = get_bootstrapped_KL_by_sub(df_free_cont_6_color, df_rand_cont_6_color, kl_bins=36, n_iters=10, sample_bins=360, empirical=True)
# Out:
# 1 / 49 subjects complete
# 2 / 49 subjects complete
# 3 / 49 subjects complete
# 4 / 49 subjects complete
# 5 / 49 subjects complete
# 6 / 49 subjects complete
# 7 / 49 subjects complete
# 8 / 49 subjects complete
# 9 / 49 subjects complete
# 10 / 49 subjects complete
# 11 / 49 subjects complete
# 12 / 49 subjects complete
# 13 / 49 subjects complete
# 14 / 49 subjects complete
# 15 / 49 subjects complete
# 16 / 49 subjects complete
# 17 / 49 subjects complete
# 18 / 49 subjects complete
# 19 / 49 subjects complete
# 20 / 49 subjects complete
# 21 / 49 subjects complete
# 22 / 49 subjects complete
# 23 / 49 subjects complete
# 24 / 49 subjects complete
# 25 / 49 subjects complete
# 26 / 49 subjects complete
# 27 / 49 subjects complete
# 28 / 49 subjects complete
# 29 / 49 subjects complete
# 30 / 49 subjects complete
# 31 / 49 subjects complete
# 32 / 49 subjects complete
# 33 / 49 subjects complete
# 34 / 49 subjects complete
# 35 / 49 subjects complete
# 36 / 49 subjects complete
# ...

# %% [markdown]
# ### Figure 3C (lower). KL divergence from relative dist distributions to uniform

# %%
def plot_bootstrapped_KL_by_sub(kl_df, color):
    
    medians = kl_df.groupby(['response', 'condition', 'subject']).samples.median().reset_index()
    ax = sns.stripplot(x='response', y='samples', hue='condition', 
                       data=medians, dodge=True, palette=color,
                       hue_order=['free', 'baseline_free', 'rand', 'baseline_rand'])
    fig = plt.gcf()
    ax.get_legend().remove()

    for cat, response in enumerate(np.sort(medians.response.unique())):
        y0 = medians[(medians.response == response) & (medians.condition == 'free')].samples
        y1 = medians[(medians.response == response) & (medians.condition == 'baseline_free')].samples
        y2 = medians[(medians.response == response) & (medians.condition == 'rand')].samples
        y3 = medians[(medians.response == response) & (medians.condition == 'baseline_rand')].samples

        x0 = cat - 0.3
        x1 = cat - 0.1
        x2 = cat + 0.1
        x3 = cat + 0.3

        plt.plot([x0, x1], [y0, y1], color=(0.5, 0.5, 0.5), linewidth=0.5)
        plt.plot([x2, x3], [y2, y3], color=(0.5, 0.5, 0.5), linewidth=0.5)
    
    return fig, ax

# %%
# plot kl medians by subject and condition (continuous)

# COLOR IN GRAYSCALE FOR COMPARISON
gray = (0.7, 0.7, 0.7)
color = [gray]*4

fig, ax = plot_bootstrapped_KL_by_sub(kl_df_color, color)

# ORIENTATION IN COLOR OVER TOP
color = [FREE_ORIENT, (0.3, 0.3, 0.3), RAND_ORIENT, (0.3, 0.3, 0.3)]
fig, ax = plot_bootstrapped_KL_by_sub(kl_df_orient, color)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.set_ylim([0, 2])
ax.set_yticks([0, 1, 2])
ax.set_xticks([])

set_export_style(fig, [ax], remove_ticklabels=False, figsize=(10, 3))

if save_fig:
    fig.savefig('../figures/fig_07-04_kl_bootstrap_ori.png', bbox_inches='tight', dpi=800)

plt.show()
